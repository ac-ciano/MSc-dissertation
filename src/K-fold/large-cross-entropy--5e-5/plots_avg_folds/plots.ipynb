# %% [markdown]
# *****AVERAGE ACROSS ALL FOLDS FIRST*****

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_paths = [
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold1_FIRST_finetune\warmup320\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold2_FIRST_finetune\warmup320\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold3_FIRST_finetune\warmup320\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold4_FIRST_finetune\warmup320\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold5_FIRST_finetune\warmup320\metrics\roberta-large_metrics.csv",
]

#load the dataframes
dataframes = [pd.read_csv(file_path) for file_path in file_paths]

#average results
avg_results = pd.concat(dataframes).groupby(level=0).mean()

# Set the style
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot F1 weighted and Accuracy on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Epoch', fontsize=14)
ax1.set_ylabel('F1 score', color=color, fontsize=14)
ax1.plot(avg_results['epoch'], avg_results['eval_f1_weighted'], color=color, linestyle='-', marker='.', markersize=4, label='Validation F1 weighted')
#ax1.plot(warmup320_df['epoch'], warmup320_df['eval_accuracy'], color='green', linestyle='-', marker='s', markersize=4, label='Validation Accuracy')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

# Create a second y-axis for the loss
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Loss', color=color, fontsize=14)  # we already handled the x-label with ax1
#ax2.plot(avg_results['epoch'], avg_results['eval_loss'], color=color, linestyle='-', marker='^', markersize=4, label='Validation Loss')
ax2.plot(avg_results['epoch'], avg_results['train_loss'], color="#003C9C", linestyle='-', marker='^', markersize=4, label='Training Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Add a title
plt.title('RoBERTa training (avg_FIRST): cross-entropy loss', fontsize=16)

# Add legends
# To combine legends from both axes, we get handles and labels from both and pass them to a single legend command
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='lower right', fontsize=12)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig("warmup320_FIRST_1fold.pdf") # Save the plot as a PDF
plt.show()

# %% [markdown]
# *****AVERAGE ACROSS ALL FOLDS SECOND*****

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_paths = [
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold1_FIRST_finetune\warmup320\fold1_SECOND_finetune\warmup340\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold2_FIRST_finetune\warmup320\fold2_SECOND_finetune\warmup340\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold3_FIRST_finetune\warmup320\fold3_SECOND_finetune\warmup340\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold4_FIRST_finetune\warmup320\fold4_SECOND_finetune\warmup340\metrics\roberta-large_metrics.csv",
    r"F:\VERO UTENTE\Desktop\Uni\dissertation\main\K-fold\large-cross-entropy--5e-5\fold5_FIRST_finetune\warmup320\fold5_SECOND_finetune\warmup340\metrics\roberta-large_metrics.csv",
]

#load the dataframes
dataframes = [pd.read_csv(file_path) for file_path in file_paths]

#average results
avg_results = pd.concat(dataframes).groupby(level=0).mean()

# Set the style
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot F1 weighted and Accuracy on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Epoch', fontsize=14)
ax1.set_ylabel('F1 score', color=color, fontsize=14)
ax1.plot(avg_results['epoch'], avg_results['eval_f1_weighted'], color=color, linestyle='-', marker='.', markersize=4, label='Validation F1 weighted')
#ax1.plot(warmup320_df['epoch'], warmup320_df['eval_accuracy'], color='green', linestyle='-', marker='s', markersize=4, label='Validation Accuracy')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

# Create a second y-axis for the loss
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Loss', color=color, fontsize=14)  # we already handled the x-label with ax1
#ax2.plot(avg_results['epoch'], avg_results['eval_loss'], color=color, linestyle='-', marker='^', markersize=4, label='Validation Loss')
ax2.plot(avg_results['epoch'], avg_results['train_loss'], color="#003C9C", linestyle='-', marker='^', markersize=4, label='Training Loss')
ax2.tick_params(axis='y', labelcolor=color)

# Add a title
plt.title('RoBERTa training (avg_FIRST): cross-entropy loss', fontsize=16)

# Add legends
# To combine legends from both axes, we get handles and labels from both and pass them to a single legend command
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='lower right', fontsize=12)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig("warmup320_FIRST_1fold.pdf") # Save the plot as a PDF
plt.show()
